# %% [markdown]
# # POS Tagging
#
# #### Problem Statement:
# _The vanilla Viterbi algorithm we had written had resulted in ~87% accuracy. The approx. 13% loss of accuracy was majorly due to the fact that when the algorithm encountered an unknown word (i.e. not present in the training set, such as 'Twitter'), it assigned an incorrect tag arbitrarily. This is because, for unknown words, the emission probabilities for all candidate tags are 0, so the algorithm arbitrarily chooses (the first) tag._
#
# _In this assignment, you need to modify the Viterbi algorithm to solve the problem of unknown words_
#
# This assignment is done using 2 methods:
#
# - Since the emission probabilities of the unknow words are "0", the state probability becomes "0" (_as a result of the product emission probability * transistion Probability_), to avoid that, for all the unknowns only the transtational probabilities are used.
#
# - Seconldy using unigram tagger & regex along with veterbi

# %%
#import Libs
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random, pprint, time
from collections import Counter

#import train test split
from sklearn.model_selection import train_test_split

# %%
#read the data
data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
print('Total number of words in data are: ',len(data))
# Out:
# Total number of words in data are:  3914

# %%
data[:2]
# Out:
# [[('Pierre', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   (',', '.'),
#   ('61', 'NUM'),
#   ('years', 'NOUN'),
#   ('old', 'ADJ'),
#   (',', '.'),
#   ('will', 'VERB'),
#   ('join', 'VERB'),
#   ('the', 'DET'),
#   ('board', 'NOUN'),
#   ('as', 'ADP'),
#   ('a', 'DET'),
#   ('nonexecutive', 'ADJ'),
#   ('director', 'NOUN'),
#   ('Nov.', 'NOUN'),
#   ('29', 'NUM'),
#   ('.', '.')],
#  [('Mr.', 'NOUN'),
#   ('Vinken', 'NOUN'),
#   ('is', 'VERB'),
#   ('chairman', 'NOUN'),
#   ('of', 'ADP'),
#   ('Elsevier', 'NOUN'),
#   ('N.V.', 'NOUN'),
#   (',', '.'),
#   ('the', 'DET'),
#   ('Dutch', 'NOUN'),
#   ('publishing', 'VERB'),
#   ('group', 'NOUN'),
#   ('.', '.')]]

# %%
#splliting the data into train & test set
random.seed(1234)
train_set, test_set = train_test_split(data, test_size=.05)

# %%
print('Shape of the train set:', len(train_set))
print('Shape of the test set:', len(test_set))
# Out:
# Shape of the train set: 3718
# Shape of the test set: 196

# %%
#creating tag of words for both train & test data
train_tagged_words = [tup for sent in train_set for tup in sent]
len(train_tagged_words)


# list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]
#print(test_run_base)
# list of untagged words
test_tagged_words = [tup[0] for tup in test_run_base]
#test_tagged_words

train_tagged_words = [tup for sent in train_set for tup in sent]

# %%
# tokens 
tokens = [pair[0] for pair in train_tagged_words]
tokens[:10]
# Out:
# ['Mr.',
#  'Oxnard',
#  'observed',
#  'that',
#  'the',
#  'situation',
#  'in',
#  'Brazil',
#  'is',
#  'also']

# %%
# vocabulary
V = set(tokens)
print(len(V))
# Out:
# 12081

# %%
# number of tags
T = set([pair[1] for pair in train_tagged_words])
print(len(T))
print(T)
# Out:
# 12
# {'VERB', 'DET', 'PRON', '.', 'PRT', 'ADV', 'X', 'NOUN', 'CONJ', 'ADP', 'ADJ', 'NUM'}

# %%
# Creating matrix for tags and words
t = len(T)
v = len(V)
w_given_t = np.zeros((t, v))

# %% [markdown]
# ## Baseline Veterbi implementation

# %%
#Computing emission probability
def word_given_tag(word, tag, train_bag = train_tagged_words):
    '''
Function to calculate p(w|t)
    '''
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list) # Denominator
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)#numerator
    return (count_w_given_tag, count_tag)

# %%
#Computing the transistion probabilities
def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    '''
Function to calculate p(t2|t1)

    '''

    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
start = time.time()
tagged_seq = Viterbi(test_tagged_words)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 823.018013715744

# %%
check = list([i for i, j in zip(tagged_seq, test_run_base) if i == j])
len(check)
# Out:
# 4687

# %%
accuracy = len(check)/len(tagged_seq)
accuracy
# Out:
# 0.922456209407597

# %%
#opening the valiation file 
with open('Test_sentences.txt') as f:
    validation_data = f.read()

#tokenization of Validatword_tokenizeenizeenize
validation_token = nltk.word_tokenize(validation_data)

# %%
#Testing the validation data
start = time.time()
tagged_seq_validation = Viterbi(validation_token)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 30.368805170059204

# %%
tagged_seq_validation
# Out:
# [('Android', 'VERB'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'VERB'),
#  ('.', '.'),
#  ('Android', 'VERB'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'VERB'),
#  ('worldwide', 'VERB'),
#  ('on', 'ADP'),
#  ('smartphones', 'VERB'),
#  ('since', 'ADP'),
#  ('2011', 'VERB'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'VERB'),
#  ('.', '.'),
#  ('Google', 'VERB'),
#  ('and', 'CONJ'),
#  ('Twitter', 'VERB'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'VERB'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'VERB'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'VERB'),
#  ("'s", 'PRT'),
#  ('firehose', 'VERB'),
#  ('.', '.'),
#  ('Twitter', 'VERB'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'VERB'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'VERB'),
#  ('with', 'ADP'),
#  ('messages', 'VERB'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'VERB'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'VERB'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'VERB'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'VERB'),
#  ('FIFA', 'VERB'),
#  ('World', 'NOUN'),
#  ('Cup', 'VERB'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'VERB'),
#  ('FIFA', 'VERB'),
#  ('World', 'NOUN'),
#  ('Cup', 'VERB'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'VERB'),
#  ('contested', 'VERB'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'VERB'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'VERB'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'VERB'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'VERB'),
#  ('invited', 'VERB'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'VERB'),
#  ('Satellite', 'VERB'),
#  ('.', '.')]

# %% [markdown]
# ### Observations from the Validation set, while using baseline Verterbi
# - _From the data it seems that the words such as Andriod, Google, Twitter are marked as DET instead of Noun, this behaviour changes with each execution!_
# - _Some problem with tagging numbers, for example 2018, is tagged as DET_

# %%
#checking the incorrected tags in the test data to check the problems
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[("n't", 'ADV'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('Italy', 'NOUN'), (('there', 'DET'), ('there', 'ADV'))],
#  [('is', 'VERB'), (('Angelo', 'VERB'), ('Angelo', 'NOUN'))],
#  [('Angelo', 'NOUN'), (('Gaja', 'VERB'), ('Gaja', 'NOUN'))],
#  [('Gaja', 'NOUN'), (('Barbaresco', 'VERB'), ('Barbaresco', 'NOUN'))],
#  [(',', '.'), (('Piero', 'VERB'), ('Piero', 'NOUN'))],
#  [('Piero', 'NOUN'), (('Antinori', 'VERB'), ('Antinori', 'NOUN'))],
#  [('La', 'NOUN'), (('Solaia', 'VERB'), ('Solaia', 'NOUN'))],
#  [('net', 'ADJ'), (('importer', 'VERB'), ('importer', 'NOUN'))],
#  [('``', '.'), (('genuine', 'VERB'), ('genuine', 'ADJ'))],
#  [('this', 'DET'), (('touchy', 'VERB'), ('touchy', 'ADJ'))],
#  [('pay', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('$', '.'), (('77,000', 'VERB'), ('77,000', 'NUM'))],
#  [('for', 'ADP'), (('free', 'ADJ'), ('free', 'ADV'))],
#  [('$', '.'), (('14.75', 'VERB'), ('14.75', 'NUM'))],
#  [('No', 'DET'), (('one', 'NUM'), ('one', 'NOUN'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('.', '.'), (('Arbitrage-related', 'VERB'), ('Arbitrage-related', 'ADJ'))],
#  [('of', 'ADP'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('the', 'DET'), (('close', 'ADJ'), ('close', 'NOUN'))],
#  [('James', 'NOUN'), (('Rill', 'VERB'), ('Rill', 'NOUN'))],
#  [('buy', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('company', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-146', 'VERB'), ('*T*-146', 'X'))],
#  [('Michael', 'NOUN'), (('Stark', 'VERB'), ('Stark', 'NOUN'))],
#  [('at', 'ADP'), (('Robertson', 'VERB'), ('Robertson', 'NOUN'))],
#  [(',', '.'), (('Stephens', 'VERB'), ('Stephens', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('budding', 'VERB'), (('logistical', 'VERB'), ('logistical', 'ADJ'))],
#  [('residential', 'ADJ'), (('renovation', 'VERB'), ('renovation', 'NOUN'))],
#  [('in', 'ADP'), (('Westport', 'VERB'), ('Westport', 'NOUN'))],
#  [('of', 'ADP'), (('punitive', 'VERB'), ('punitive', 'ADJ'))],
#  [('to', 'PRT'), (('license', 'NOUN'), ('license', 'VERB'))],
#  [('--', '.'), (('271,124', 'VERB'), ('271,124', 'NUM'))],
#  [('the', 'DET'), (('400,000', 'VERB'), ('400,000', 'NUM'))],
#  [('Peter', 'NOUN'), (('Huber', 'VERB'), ('Huber', 'NOUN'))],
#  [('an', 'DET'), (('anti-miscarriage', 'VERB'), ('anti-miscarriage', 'ADJ'))],
#  [('sell', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('stock', 'NOUN'), (('short', 'ADJ'), ('short', 'ADV'))],
#  [('buying', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('0', 'X'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('month', 'NOUN'), (('before', 'ADP'), ('before', 'ADV'))],
#  [('its', 'PRON'), (('F-series', 'VERB'), ('F-series', 'NOUN'))],
#  [('F-series', 'NOUN'), (('Crew', 'VERB'), ('Crew', 'NOUN'))],
#  [('Crew', 'NOUN'), (('Cab', 'VERB'), ('Cab', 'NOUN'))],
#  [('Cab', 'NOUN'), (('pickups', 'VERB'), ('pickups', 'NOUN'))],
#  [('ads', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('The', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('of', 'ADP'), (('Delegates', 'VERB'), ('Delegates', 'NOUN'))],
#  [('IRS', 'NOUN'), (('reporting', 'VERB'), ('reporting', 'NOUN'))],
#  [('$', '.'), (('6,500', 'VERB'), ('6,500', 'NUM'))],
#  [('send', 'VERB'), (('continuously', 'VERB'), ('continuously', 'ADV'))],
#  [('colored', 'VERB'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('of', 'ADP'), (('fiber-end', 'VERB'), ('fiber-end', 'ADJ'))],
#  [('fiber-end', 'ADJ'), (('bunches', 'VERB'), ('bunches', 'NOUN'))],
#  [('how', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('the', 'DET'), (('very', 'ADV'), ('very', 'ADJ'))],
#  [('very', 'ADJ'), (('building', 'VERB'), ('building', 'NOUN'))],
#  [('*ICH*-4', 'X'), (('that', 'ADP'), ('that', 'DET'))],
#  [('as', 'ADP'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('assumed', 'VERB'), (('*-121', 'VERB'), ('*-121', 'X'))],
#  [('B.', 'NOUN'), (('Langner', 'VERB'), ('Langner', 'NOUN'))],
#  [('in', 'ADP'), (('rankings', 'VERB'), ('rankings', 'NOUN'))],
#  [('risen', 'VERB'), (('smartly', 'VERB'), ('smartly', 'ADV'))],
#  [('with', 'ADP'), (('even', 'ADV'), ('even', 'ADJ'))],
#  [('.', '.'), (('Recently', 'VERB'), ('Recently', 'ADV'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('specialized', 'VERB'), (('boilers', 'VERB'), ('boilers', 'NOUN'))],
#  [('and', 'CONJ'), (('pipes', 'VERB'), ('pipes', 'NOUN'))],
#  [('own', 'ADJ'), (('Lurgi', 'VERB'), ('Lurgi', 'NOUN'))],
#  [('Lurgi', 'NOUN'), (('G.m.b', 'VERB'), ('G.m.b', 'NOUN'))],
#  [('plant', 'NOUN'), (('engineering', 'NOUN'), ('engineering', 'VERB'))],
#  [('into', 'ADP'), (('chaos', 'VERB'), ('chaos', 'NOUN'))],
#  [("'s", 'PRT'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('trial', 'NOUN'), (('balloon', 'VERB'), ('balloon', 'NOUN'))],
#  [('broken', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('as', 'ADP'), (('Mellon', 'VERB'), ('Mellon', 'NOUN'))],
#  [("'s", 'PRT'), (('nine-year', 'VERB'), ('nine-year', 'ADJ'))],
#  [('$', '.'), (('5.7', 'VERB'), ('5.7', 'NUM'))],
#  [('$', '.'), (('274', 'VERB'), ('274', 'NUM'))],
#  [('nearly', 'ADV'), (('tenfold', 'VERB'), ('tenfold', 'ADV'))],
#  [("'s", 'PRT'), (('launch', 'VERB'), ('launch', 'NOUN'))],
#  [('a', 'DET'), (('darned', 'VERB'), ('darned', 'ADV'))],
#  [('a', 'DET'), (('willingness', 'VERB'), ('willingness', 'NOUN'))],
#  [('Assuming', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('in', 'ADP'), (('universities', 'VERB'), ('universities', 'NOUN'))],
#  [('H.', 'NOUN'), (('Strother', 'VERB'), ('Strother', 'NOUN'))],
#  [('.', '.'), (('Everyone', 'VERB'), ('Everyone', 'NOUN'))],
#  [('is', 'VERB'), (('utterly', 'VERB'), ('utterly', 'ADV'))],
#  [('utterly', 'ADV'), (('incapable', 'VERB'), ('incapable', 'ADJ'))],
#  [('help', 'VERB'), (('deserving', 'VERB'), ('deserving', 'ADJ'))],
#  [('some', 'DET'), (('billion-dollar', 'VERB'), ('billion-dollar', 'ADJ'))],
#  [('billion-dollar', 'ADJ'), (('morass', 'VERB'), ('morass', 'NOUN'))],
#  [('Plans', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('advertisers', 'NOUN'), (('discounts', 'VERB'), ('discounts', 'NOUN'))],
#  [('permanent', 'ADJ'), (('fixtures', 'VERB'), ('fixtures', 'NOUN'))],
#  [('and', 'CONJ'), (('Mortimer', 'VERB'), ('Mortimer', 'NOUN'))],
#  [('B.', 'NOUN'), (('Zuckerman', 'VERB'), ('Zuckerman', 'NOUN'))],
#  [('These', 'DET'), (('vertically', 'VERB'), ('vertically', 'ADV'))],
#  [('integrated', 'VERB'), (('combines', 'VERB'), ('combines', 'NOUN'))],
#  [('their', 'PRON'), (('start', 'VERB'), ('start', 'NOUN'))],
#  [("'s", 'PRT'), (('feudal', 'VERB'), ('feudal', 'ADJ'))],
#  [(',', '.'), (('deal', 'NOUN'), ('deal', 'VERB'))],
#  [('deal', 'VERB'), (('globally', 'VERB'), ('globally', 'ADV'))],
#  [('and', 'CONJ'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('remains', 'VERB'), (('confident', 'VERB'), ('confident', 'ADJ'))],
#  [('future', 'ADJ'),
#   (('creditworthiness', 'VERB'), ('creditworthiness', 'NOUN'))],
#  [('of', 'ADP'), (('Wilmington', 'VERB'), ('Wilmington', 'NOUN'))],
#  [('of', 'ADP'), (('neoprene', 'VERB'), ('neoprene', 'NOUN'))],
#  [('synthetic', 'ADJ'), (('rubber', 'VERB'), ('rubber', 'NOUN'))],
#  [('put', 'VERB'), (('*-41', 'VERB'), ('*-41', 'X'))],
#  [('*-41', 'X'), (('together', 'ADV'), ('together', 'PRT'))],
#  [('by', 'ADP'), (('Blackstone', 'VERB'), ('Blackstone', 'NOUN'))],
#  [('are', 'VERB'), (('worth', 'ADJ'), ('worth', 'ADP'))],
#  [('for', 'ADP'), (('aesthetic', 'VERB'), ('aesthetic', 'ADJ'))],
#  [('aesthetic', 'ADJ'), (('reasons', 'VERB'), ('reasons', 'NOUN'))],
#  [('one', 'NUM'), (('famed', 'VERB'), ('famed', 'ADJ'))],
#  [('a', 'DET'), (('distinct', 'VERB'), ('distinct', 'ADJ'))],
#  [('computer', 'NOUN'), (('file', 'VERB'), ('file', 'NOUN'))],
#  [('file', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('of', 'ADP'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('and', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('as', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('What', 'PRON'), (('*T*-164', 'VERB'), ('*T*-164', 'X'))],
#  [('*T*-164', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('firms', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-255', 'VERB'), ('*T*-255', 'X'))],
#  [('an', 'DET'), (('actor', 'VERB'), ('actor', 'NOUN'))],
#  [('the', 'DET'), (('inheritor', 'VERB'), ('inheritor', 'NOUN'))],
#  [('of', 'ADP'), (('Charlie', 'VERB'), ('Charlie', 'NOUN'))],
#  [('.', '.'), (('Shipments', 'VERB'), ('Shipments', 'NOUN'))],
#  [('relatively', 'ADV'), (('level', 'NOUN'), ('level', 'ADJ'))],
#  [('which', 'DET'), (('*T*-251', 'VERB'), ('*T*-251', 'X'))],
#  [('by', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('a', 'DET'), (('slowing', 'NOUN'), ('slowing', 'VERB'))],
#  [('at', 'ADP'), (('Pitney', 'VERB'), ('Pitney', 'NOUN'))],
#  [('Pitney', 'NOUN'), (('Bowes', 'VERB'), ('Bowes', 'NOUN'))],
#  [('a', 'DET'), (('sheaf', 'VERB'), ('sheaf', 'NOUN'))],
#  [('can', 'VERB'), (('trust', 'NOUN'), ('trust', 'VERB'))],
#  [('$', '.'), (('5.8', 'VERB'), ('5.8', 'NUM'))],
#  [('the', 'DET'), (('Monopolies', 'VERB'), ('Monopolies', 'NOUN'))],
#  [('and', 'CONJ'), (('Mergers', 'VERB'), ('Mergers', 'NOUN'))],
#  [('replacement', 'NOUN'), (('tires', 'VERB'), ('tires', 'NOUN'))],
#  [('was', 'VERB'), (('outraged', 'VERB'), ('outraged', 'ADJ'))],
#  [('dominated', 'VERB'), (('*-41', 'VERB'), ('*-41', 'X'))],
#  [('the', 'DET'), (('heirs', 'VERB'), ('heirs', 'NOUN'))],
#  [('East', 'NOUN'), (('German', 'ADJ'), ('German', 'NOUN'))],
#  [('leader', 'NOUN'), (('Krenz', 'VERB'), ('Krenz', 'NOUN'))],
#  [('democratic', 'ADJ'), (('freedoms', 'VERB'), ('freedoms', 'NOUN'))],
#  [('showing', 'VERB'), (('support', 'VERB'), ('support', 'NOUN'))],
#  [('the', 'DET'), (('renovation', 'VERB'), ('renovation', 'NOUN'))],
#  [('for', 'ADP'), (('socialism', 'VERB'), ('socialism', 'NOUN'))],
#  [('one', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-70', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [("'s", 'VERB'), (('captivating', 'VERB'), ('captivating', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('seem', 'VERB'), (('disagreeable', 'VERB'), ('disagreeable', 'ADJ'))],
#  [('increasing', 'VERB'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('that', 'ADV'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('*ICH*-1', 'X'), (('Gayle', 'VERB'), ('Gayle', 'NOUN'))],
#  [('incentive', 'NOUN'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('opened', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('can', 'VERB'), ('can', 'NOUN'))],
#  [('of', 'ADP'), (('worms', 'VERB'), ('worms', 'NOUN'))],
#  [('of', 'ADP'), (('gallium', 'VERB'), ('gallium', 'NOUN'))],
#  [('gallium', 'NOUN'), (('arsenide', 'VERB'), ('arsenide', 'NOUN'))],
#  [('and', 'CONJ'), (('minute', 'NOUN'), ('minute', 'ADJ'))],
#  [('special', 'ADJ'), (('robotic', 'VERB'), ('robotic', 'ADJ'))],
#  [('stepped', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('not', 'ADV'), (('panic', 'NOUN'), ('panic', 'VERB'))],
#  [('taken', 'VERB'), (('off', 'PRT'), ('off', 'ADV'))],
#  [('of', 'ADP'), (('home-market', 'VERB'), ('home-market', 'ADJ'))],
#  [('home-market', 'ADJ'), (('stock-index', 'ADJ'), ('stock-index', 'NOUN'))],
#  [('and', 'CONJ'), (('Osaka', 'VERB'), ('Osaka', 'NOUN'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('currently', 'ADV'), (('about', 'ADP'), ('about', 'ADV'))],
#  [(',', '.'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('commercial', 'ADJ'),
#   (('property\\/casualty', 'VERB'), ('property\\/casualty', 'NOUN'))],
#  [('personal', 'ADJ'),
#   (('property\\/casualty', 'VERB'), ('property\\/casualty', 'NOUN'))],
#  [('somewhat', 'ADV'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('anticipated', 'VERB'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('Italian', 'ADJ'), (('ancestry', 'VERB'), ('ancestry', 'NOUN'))],
#  [('in', 'ADP'), (('Puerto', 'VERB'), ('Puerto', 'NOUN'))],
#  [('Puerto', 'NOUN'), (('Rico', 'VERB'), ('Rico', 'NOUN'))],
#  [('a', 'DET'), (('litany', 'VERB'), ('litany', 'NOUN'))],
#  [('by', 'ADP'), (('Osborn', 'VERB'), ('Osborn', 'NOUN'))],
#  [('and', 'CONJ'), (('Desai', 'VERB'), ('Desai', 'NOUN'))],
#  [(',', '.'), (('benefits', 'NOUN'), ('benefits', 'VERB'))],
#  [('the', 'DET'), (('backing', 'VERB'), ('backing', 'NOUN'))],
#  [('Credit', 'NOUN'), (('Suisse', 'VERB'), ('Suisse', 'NOUN'))],
#  [('Consolidated', 'NOUN'), (('Rail', 'VERB'), ('Rail', 'NOUN'))],
#  [('transporting', 'VERB'), (('autos', 'VERB'), ('autos', 'NOUN'))],
#  [('the', 'DET'), (('Kensington', 'VERB'), ('Kensington', 'NOUN'))],
#  [('years', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('a', 'DET'), (('constituent', 'VERB'), ('constituent', 'NOUN'))],
#  [('legislative', 'ADJ'), (('technique', 'VERB'), ('technique', 'NOUN'))],
#  [('.', '.'), (('Mostly', 'VERB'), ('Mostly', 'ADV'))],
#  [('to', 'PRT'), (('self-esteem', 'VERB'), ('self-esteem', 'NOUN'))],
#  [('the', 'DET'), (('Second', 'ADJ'), ('Second', 'NOUN'))],
#  [('of', 'ADP'), (('Appeals', 'VERB'), ('Appeals', 'NOUN'))],
#  [('.', '.'), (('Seed', 'VERB'), ('Seed', 'NOUN'))],
#  [('for', 'ADP'), (('Jail', 'VERB'), ('Jail', 'NOUN'))],
#  [('Jail', 'NOUN'), (('Solution', 'VERB'), ('Solution', 'NOUN'))],
#  [('Take', 'VERB'), (('Root', 'VERB'), ('Root', 'NOUN'))],
#  [('which', 'DET'), (('*T*-148', 'VERB'), ('*T*-148', 'X'))],
#  [('expanding', 'VERB'),
#   (('manufacturing', 'VERB'), ('manufacturing', 'NOUN'))],
#  [('Chinese', 'ADJ'), (('dissident', 'VERB'), ('dissident', 'NOUN'))],
#  [('Fang', 'NOUN'), (('Lizhi', 'VERB'), ('Lizhi', 'NOUN'))],
#  [('Li', 'NOUN'), (('Shuxian', 'VERB'), ('Shuxian', 'NOUN'))],
#  [('took', 'VERB'), (('refuge', 'VERB'), ('refuge', 'NOUN'))],
#  [('.', '.'), (('Paris', 'VERB'), ('Paris', 'NOUN'))],
#  [(',', '.'), (('Brussels', 'VERB'), ('Brussels', 'NOUN'))],
#  [('and', 'CONJ'), (('Milan', 'VERB'), ('Milan', 'NOUN'))],
#  [('Svenska', 'NOUN'), (('Handelsbanken', 'VERB'), ('Handelsbanken', 'NOUN'))],
#  [('a', 'DET'), (('greenmailer', 'VERB'), ('greenmailer', 'NOUN'))],
#  [('to', 'PRT'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('of', 'ADP'), (('major-league', 'VERB'), ('major-league', 'ADJ'))],
#  [('the', 'DET'), (('phase-out', 'VERB'), ('phase-out', 'NOUN'))],
#  [('recent', 'ADJ'), (('closing', 'ADJ'), ('closing', 'NOUN'))],
#  [('a', 'DET'), (('Hostess', 'VERB'), ('Hostess', 'NOUN'))],
#  [('cake', 'NOUN'), (('bakery', 'VERB'), ('bakery', 'NOUN'))],
#  [('U.S.', 'NOUN'), (('grains', 'VERB'), ('grains', 'NOUN'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('drug', 'NOUN'), (('trafficking', 'VERB'), ('trafficking', 'NOUN'))],
#  [('the', 'DET'), (('Andean', 'VERB'), ('Andean', 'ADJ'))],
#  [('.', '.'), (('Packages', 'VERB'), ('Packages', 'NOUN'))],
#  [('The', 'DET'), (('beds', 'VERB'), ('beds', 'NOUN'))],
#  [('the', 'DET'), (('Bowery', 'VERB'), ('Bowery', 'NOUN'))],
#  [('Bowery', 'NOUN'), (('Mission', 'VERB'), ('Mission', 'NOUN'))],
#  [('seem', 'VERB'), (('far', 'ADV'), ('far', 'ADJ'))],
#  [('far', 'ADJ'), (('drearier', 'VERB'), ('drearier', 'ADV'))],
#  [('a', 'DET'), (('vitriolic', 'VERB'), ('vitriolic', 'ADJ'))],
#  [('A', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('``', '.'), (('Norwegian', 'VERB'), ('Norwegian', 'NOUN'))],
#  [('every', 'DET'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('be', 'VERB'), (('fluent', 'VERB'), ('fluent', 'ADJ'))],
#  [('Beatles', 'NOUN'), (('lyrics', 'VERB'), ('lyrics', 'NOUN'))],
#  [('sold', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('a', 'DET'), (('Traverse', 'VERB'), ('Traverse', 'NOUN'))],
#  [('who', 'PRON'), (('*T*-103', 'VERB'), ('*T*-103', 'X'))],
#  [('presidents', 'NOUN'), (('*PPA*-1', 'VERB'), ('*PPA*-1', 'X'))],
#  [('the', 'DET'), (('Civil', 'VERB'), ('Civil', 'NOUN'))],
#  [('such', 'ADJ'), (('lawmaking', 'VERB'), ('lawmaking', 'ADJ'))],
#  [('a', 'DET'), (('Delaware', 'VERB'), ('Delaware', 'NOUN'))],
#  [('of', 'ADP'), (('Dunkin', 'VERB'), ('Dunkin', 'NOUN'))],
#  [('ownership', 'NOUN'), (('plans', 'VERB'), ('plans', 'NOUN'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('to', 'PRT'), (('American-style', 'VERB'), ('American-style', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-253', 'VERB'), ('*T*-253', 'X'))],
#  [('leading', 'VERB'), (('Sauternes', 'VERB'), ('Sauternes', 'NOUN'))],
#  [('well', 'ADV'), (('over', 'ADP'), ('over', 'ADV'))],
#  [('a', 'DET'), (('lighter', 'VERB'), ('lighter', 'ADJ'))],
#  [('the', 'DET'), (('spectacularly', 'VERB'), ('spectacularly', 'ADV'))],
#  [('but', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('main', 'ADJ'), (('index-arbitrage', 'ADJ'), ('index-arbitrage', 'NOUN'))],
#  [('``', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('information', 'NOUN'),
#   (('domestically', 'VERB'), ('domestically', 'ADV'))],
#  [('``', '.'), (('clouds', 'VERB'), ('clouds', 'NOUN'))],
#  [('blue', 'ADJ'), (('dust', 'VERB'), ('dust', 'NOUN'))],
#  [('though', 'ADP'), (('exhaust', 'VERB'), ('exhaust', 'NOUN'))],
#  [('their', 'PRON'), (('monopoly', 'VERB'), ('monopoly', 'NOUN'))],
#  [('too', 'ADV'), (('upset', 'VERB'), ('upset', 'ADJ'))],
#  [('The', 'DET'), (('declaration', 'VERB'), ('declaration', 'NOUN'))],
#  [('by', 'ADP'), (('Economy', 'VERB'), ('Economy', 'NOUN'))],
#  [('Minister', 'NOUN'), (('Nestor', 'VERB'), ('Nestor', 'NOUN'))],
#  [('all', 'DET'), (('avenues', 'VERB'), ('avenues', 'NOUN'))],
#  [('the', 'DET'), (('illegality', 'VERB'), ('illegality', 'NOUN'))],
#  [('ruling', 'NOUN'), (('work', 'NOUN'), ('work', 'VERB'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('all', 'DET'), (('pension-fund', 'VERB'), ('pension-fund', 'ADJ'))],
#  [("'s", 'PRT'), (('offering', 'VERB'), ('offering', 'NOUN'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('are', 'VERB'), (('infrequent', 'VERB'), ('infrequent', 'ADJ'))],
#  [('the', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('In', 'ADP'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [('fell', 'VERB'), (('63.79', 'VERB'), ('63.79', 'NUM'))],
#  [('to', 'PRT'), (('35500.64', 'VERB'), ('35500.64', 'NUM'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('principal', 'ADJ'), (('fights', 'VERB'), ('fights', 'NOUN'))],
#  [('book', 'NOUN'), (('pirates', 'VERB'), ('pirates', 'NOUN'))],
#  [('copper', 'NOUN'), (('mine', 'ADJ'), ('mine', 'NOUN'))],
#  [('been', 'VERB'), (('inoperative', 'VERB'), ('inoperative', 'ADJ'))],
#  [('by', 'ADP'), (('native', 'VERB'), ('native', 'ADJ'))],
#  [('native', 'ADJ'), (('landowners', 'VERB'), ('landowners', 'NOUN'))],
#  [('the', 'DET'), (('removal', 'VERB'), ('removal', 'NOUN'))],
#  [('perceives', 'VERB'), (('*T*-183', 'VERB'), ('*T*-183', 'X'))],
#  [('*U*', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('play', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'VERB'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'VERB'), ('suitors', 'NOUN'))],
#  [('to', 'PRT'), (('audit', 'NOUN'), ('audit', 'VERB'))],
#  [('and', 'CONJ'), (('refund', 'NOUN'), ('refund', 'VERB'))],
#  [('partly', 'ADV'), (('one', 'NUM'), ('one', 'NOUN'))],
#  [('personal', 'ADJ'), (('downfall', 'VERB'), ('downfall', 'NOUN'))],
#  [('well-known', 'ADJ'),
#   (('detective-story', 'VERB'), ('detective-story', 'NOUN'))],
#  [(',', '.'), (('English', 'NOUN'), ('English', 'ADJ'))],
#  [('English', 'ADJ'), (('novelist', 'VERB'), ('novelist', 'NOUN'))],
#  [('its', 'PRON'), (('satisfaction', 'VERB'), ('satisfaction', 'NOUN'))],
#  [('in', 'ADP'), (('mathematical', 'VERB'), ('mathematical', 'ADJ'))],
#  [('mathematical', 'ADJ'),
#   (('completeness', 'VERB'), ('completeness', 'NOUN'))],
#  [('mechanical', 'ADJ'), (('perfection', 'VERB'), ('perfection', 'NOUN'))],
#  [('a', 'DET'), (('tremendous', 'VERB'), ('tremendous', 'ADJ'))],
#  [('some', 'DET'), (('flexibility', 'VERB'), ('flexibility', 'NOUN'))],
#  [('high', 'ADJ'), (('prevalance', 'VERB'), ('prevalance', 'NOUN'))],
#  [('and', 'CONJ'), (('alcoholism', 'VERB'), ('alcoholism', 'NOUN'))],
#  [(',', '.'), (('tight', 'ADV'), ('tight', 'ADJ'))],
#  [('tight', 'ADJ'), (('facial', 'VERB'), ('facial', 'ADJ'))],
#  [('facial', 'ADJ'), (('shot', 'VERB'), ('shot', 'NOUN'))],
#  [('the', 'DET'), (('brain', 'VERB'), ('brain', 'NOUN'))],
#  [('a', 'DET'), (('patient', 'VERB'), ('patient', 'NOUN'))],
#  [('Red', 'NOUN'), (('Rock', 'VERB'), ('Rock', 'NOUN'))],
#  [('Rock', 'NOUN'), (('Terrace', 'VERB'), ('Terrace', 'NOUN'))],
#  [('the', 'DET'), (('Dunn', 'VERB'), ('Dunn', 'NOUN'))],
#  [('.', '.'), (('Above', 'VERB'), ('Above', 'ADP'))],
#  [('extremely', 'ADV'), (('confused', 'ADJ'), ('confused', 'VERB'))],
#  [('is', 'VERB'), (('furious', 'VERB'), ('furious', 'ADJ'))],
#  [('Combo', 'NOUN'), (('microwave', 'VERB'), ('microwave', 'NOUN'))],
#  [('``', '.'), (('In', 'ADP'), ('In', 'NOUN'))],
#  [("''", '.'), (('column', 'VERB'), ('column', 'NOUN'))],
#  [('and', 'CONJ'), (('apparel', 'VERB'), ('apparel', 'NOUN'))],
#  [('apparel', 'NOUN'), (('trade', 'VERB'), ('trade', 'NOUN'))],
#  [('trade', 'NOUN'), (('agreements', 'VERB'), ('agreements', 'NOUN'))],
#  [('.', '.'), (('Professors', 'VERB'), ('Professors', 'NOUN'))],
#  [('and', 'CONJ'), (('Laurence', 'VERB'), ('Laurence', 'NOUN'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('at', 'ADP'), (('mid-afternoon', 'VERB'), ('mid-afternoon', 'ADJ'))],
#  [('at', 'ADP'), (('260', 'VERB'), ('260', 'NUM'))],
#  [('``', '.'), (('melt-textured', 'VERB'), ('melt-textured', 'ADJ'))],
#  [('*', 'X'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('due', 'ADJ'), (('1995', 'VERB'), ('1995', 'NUM'))],
#  [('fell', 'VERB'), (('9\\/32', 'VERB'), ('9\\/32', 'NUM'))],
#  [('to', 'PRT'), (('103', 'VERB'), ('103', 'NUM'))],
#  [('yield', 'VERB'), (('11.10', 'VERB'), ('11.10', 'NUM'))],
#  [('keep', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('standard', 'ADJ'), (('benchmarks', 'VERB'), ('benchmarks', 'NOUN'))],
#  [('a', 'DET'), (('buy-out', 'NOUN'), ('buy-out', 'ADJ'))],
#  [('Hutton', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('of', 'ADP'), (('gelatin', 'VERB'), ('gelatin', 'NOUN'))],
#  [('gelatin', 'NOUN'), (('capsules', 'VERB'), ('capsules', 'NOUN'))],
#  [('its', 'PRON'),
#   (('non-encapsulating', 'VERB'), ('non-encapsulating', 'ADJ'))],
#  [('For', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('his', 'PRON'), (('destination', 'VERB'), ('destination', 'NOUN'))],
#  [('a', 'DET'), (('companion', 'VERB'), ('companion', 'NOUN'))],
#  [('attack', 'NOUN'), (('commercials', 'VERB'), ('commercials', 'NOUN'))],
#  [('commercials', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*U*', 'X'), (('write-off', 'VERB'), ('write-off', 'NOUN'))],
#  [('capitalized', 'VERB'), (('servicing', 'VERB'), ('servicing', 'NOUN'))],
#  [('home', 'NOUN'), (('financing', 'NOUN'), ('financing', 'VERB'))],
#  [('The', 'DET'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [("'s", 'PRT'), (('offerings', 'VERB'), ('offerings', 'NOUN'))],
#  [('and', 'CONJ'), (('pricings', 'VERB'), ('pricings', 'NOUN'))],
#  [('and', 'CONJ'), (('non-U.S.', 'VERB'), ('non-U.S.', 'NOUN'))],
#  [('and', 'CONJ'), (('syndicate', 'VERB'), ('syndicate', 'NOUN'))],
#  [('early', 'ADJ'), (('1980s', 'NUM'), ('1980s', 'NOUN'))],
#  [('its', 'PRON'), (('glory', 'VERB'), ('glory', 'NOUN'))],
#  [('glory', 'NOUN'), (('*PPA*-1', 'VERB'), ('*PPA*-1', 'X'))],
#  [('the', 'DET'), (('yellow', 'VERB'), ('yellow', 'ADJ'))],
#  [('yellow', 'ADJ'), (('bricks', 'VERB'), ('bricks', 'NOUN'))],
#  [('broad', 'ADJ'), (('facade', 'VERB'), ('facade', 'NOUN'))],
#  [('their', 'PRON'), (('farms', 'VERB'), ('farms', 'NOUN'))],
#  [('``', '.'), (('Nasty', 'VERB'), ('Nasty', 'ADJ'))],
#  [('Nasty', 'ADJ'), (('innuendoes', 'VERB'), ('innuendoes', 'NOUN'))],
#  [('John', 'NOUN'), (('Siegal', 'VERB'), ('Siegal', 'NOUN'))],
#  [('corruption', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("''", '.'), (('High', 'NOUN'), ('High', 'ADJ'))],
#  [('--', '.'), (('a', 'DET'), ('a', 'ADP'))],
#  [('computer', 'NOUN'), (('lab', 'VERB'), ('lab', 'NOUN'))],
#  [(',', '.'), (('grants', 'VERB'), ('grants', 'NOUN'))],
#  [('the', 'DET'), (('superintendent', 'VERB'), ('superintendent', 'NOUN'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('by', 'ADP'), (('IBC', 'VERB'), ('IBC', 'NOUN'))],
#  [('a', 'DET'), (('fraction', 'VERB'), ('fraction', 'NOUN'))],
#  [('a', 'DET'), (('labor-backed', 'VERB'), ('labor-backed', 'ADJ'))],
#  [('amendment', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('purchase', 'NOUN'), ('purchase', 'VERB'))],
#  [('previously', 'ADV'), (('that', 'ADP'), ('that', 'DET'))],
#  [('questionable', 'ADJ'), (('properties', 'VERB'), ('properties', 'NOUN'))],
#  [('.', '.'), (('Against', 'VERB'), ('Against', 'ADP'))],
#  [('a', 'DET'), (('shot', 'VERB'), ('shot', 'NOUN'))],
#  [('of', 'ADP'), (('Monticello', 'VERB'), ('Monticello', 'NOUN'))],
#  [('announcer', 'NOUN'), (('talks', 'NOUN'), ('talks', 'VERB'))],
#  [('individual', 'ADJ'), (('liberty', 'VERB'), ('liberty', 'NOUN'))],
#  [("''", '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('that', 'ADP'), (('Virginians', 'VERB'), ('Virginians', 'NOUN'))],
#  [('for', 'ADP'), (('generations', 'VERB'), ('generations', 'NOUN'))]]

# %% [markdown]
# _Unknown words, which are not in training dataset are getting tagged incorrectly, to improve the efficency of the model, lets do some modification on the Veterbi algorithm._

# %% [markdown]
# ## Modification #1
#
# _In this method, its implied that unkown words only has the transition probabilities_

# %%
#modification #2
def viterbi_modification_1(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    tokens = list(set([pair[0] for pair in train_bag]))
    unknown_word = [word for word in words if word not in tokens]
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            if word in unknown_word:
                state_probability = transition_p
            else:
                state_probability = emission_p * transition_p
            
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
start = time.time()
tagged_seq_1 = viterbi_modification_1(test_tagged_words)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 810.278270483017

# %%
check_1 = [i for i, j in zip(tagged_seq_1, test_run_base) if i == j]

# %%
accuracy_modification_1 = len(check_1)/len(tagged_seq_1)
accuracy_modification_1
# Out:
# 0.940759692973824

# %%
#checking the incorrected tags in the test data to check the problems
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq_1, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[("n't", 'ADV'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('Italy', 'NOUN'), (('there', 'DET'), ('there', 'ADV'))],
#  [('is', 'VERB'), (('Angelo', 'X'), ('Angelo', 'NOUN'))],
#  [('Angelo', 'NOUN'), (('Gaja', 'VERB'), ('Gaja', 'NOUN'))],
#  [('Gaja', 'NOUN'), (('Barbaresco', 'X'), ('Barbaresco', 'NOUN'))],
#  [('``', '.'), (('genuine', 'NOUN'), ('genuine', 'ADJ'))],
#  [('this', 'DET'), (('touchy', 'NOUN'), ('touchy', 'ADJ'))],
#  [('pay', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('$', '.'), (('77,000', 'NOUN'), ('77,000', 'NUM'))],
#  [('for', 'ADP'), (('free', 'ADJ'), ('free', 'ADV'))],
#  [('$', '.'), (('14.75', 'NOUN'), ('14.75', 'NUM'))],
#  [('No', 'DET'), (('one', 'NUM'), ('one', 'NOUN'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('.', '.'), (('Arbitrage-related', 'NOUN'), ('Arbitrage-related', 'ADJ'))],
#  [('of', 'ADP'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('the', 'DET'), (('close', 'ADJ'), ('close', 'NOUN'))],
#  [('buy', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('company', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-146', 'DET'), ('*T*-146', 'X'))],
#  [('at', 'ADP'), (('Robertson', 'DET'), ('Robertson', 'NOUN'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('budding', 'VERB'), (('logistical', 'X'), ('logistical', 'ADJ'))],
#  [('in', 'ADP'), (('Westport', 'DET'), ('Westport', 'NOUN'))],
#  [('of', 'ADP'), (('punitive', 'DET'), ('punitive', 'ADJ'))],
#  [('to', 'PRT'), (('license', 'NOUN'), ('license', 'VERB'))],
#  [('--', '.'), (('271,124', 'NOUN'), ('271,124', 'NUM'))],
#  [('the', 'DET'), (('400,000', 'NOUN'), ('400,000', 'NUM'))],
#  [('maker', 'NOUN'), (('introduces', 'NOUN'), ('introduces', 'VERB'))],
#  [('an', 'DET'), (('anti-miscarriage', 'NOUN'), ('anti-miscarriage', 'ADJ'))],
#  [('sell', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('stock', 'NOUN'), (('short', 'ADJ'), ('short', 'ADV'))],
#  [('buying', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('0', 'X'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('month', 'NOUN'), (('before', 'ADP'), ('before', 'ADV'))],
#  [('its', 'PRON'), (('F-series', 'VERB'), ('F-series', 'NOUN'))],
#  [('F-series', 'NOUN'), (('Crew', 'X'), ('Crew', 'NOUN'))],
#  [('Crew', 'NOUN'), (('Cab', 'VERB'), ('Cab', 'NOUN'))],
#  [('Cab', 'NOUN'), (('pickups', 'X'), ('pickups', 'NOUN'))],
#  [('ads', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('The', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('of', 'ADP'), (('Delegates', 'DET'), ('Delegates', 'NOUN'))],
#  [('1985', 'NUM'), (('condemning', 'NOUN'), ('condemning', 'VERB'))],
#  [('IRS', 'NOUN'), (('reporting', 'VERB'), ('reporting', 'NOUN'))],
#  [('$', '.'), (('6,500', 'NOUN'), ('6,500', 'NUM'))],
#  [('send', 'VERB'), (('continuously', 'X'), ('continuously', 'ADV'))],
#  [('changing', 'VERB'), (('colored', 'X'), ('colored', 'VERB'))],
#  [('colored', 'VERB'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('of', 'ADP'), (('fiber-end', 'DET'), ('fiber-end', 'ADJ'))],
#  [('how', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('the', 'DET'), (('very', 'ADV'), ('very', 'ADJ'))],
#  [('very', 'ADJ'), (('building', 'VERB'), ('building', 'NOUN'))],
#  [('*ICH*-4', 'X'), (('that', 'ADP'), ('that', 'DET'))],
#  [('as', 'ADP'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('in', 'ADP'), (('rankings', 'DET'), ('rankings', 'NOUN'))],
#  [('risen', 'VERB'), (('smartly', 'X'), ('smartly', 'ADV'))],
#  [('with', 'ADP'), (('even', 'ADV'), ('even', 'ADJ'))],
#  [('.', '.'), (('Recently', 'NOUN'), ('Recently', 'ADV'))],
#  [('Drexel', 'NOUN'), (('circulated', 'NOUN'), ('circulated', 'VERB'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('specialized', 'VERB'), (('boilers', 'X'), ('boilers', 'NOUN'))],
#  [('plant', 'NOUN'), (('engineering', 'NOUN'), ('engineering', 'VERB'))],
#  [('into', 'ADP'), (('chaos', 'DET'), ('chaos', 'NOUN'))],
#  [("'s", 'PRT'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('have', 'VERB'), (('floated', 'X'), ('floated', 'VERB'))],
#  [('broken', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('as', 'ADP'), (('Mellon', 'DET'), ('Mellon', 'NOUN'))],
#  [("'s", 'PRT'), (('nine-year', 'VERB'), ('nine-year', 'ADJ'))],
#  [('$', '.'), (('5.7', 'NOUN'), ('5.7', 'NUM'))],
#  [('$', '.'), (('274', 'NOUN'), ('274', 'NUM'))],
#  [('nearly', 'ADV'), (('tenfold', 'VERB'), ('tenfold', 'ADV'))],
#  [("'s", 'PRT'), (('launch', 'VERB'), ('launch', 'NOUN'))],
#  [('legislation', 'NOUN'), (('curbing', 'NOUN'), ('curbing', 'VERB'))],
#  [('a', 'DET'), (('darned', 'NOUN'), ('darned', 'ADV'))],
#  [('Assuming', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('in', 'ADP'), (('universities', 'DET'), ('universities', 'NOUN'))],
#  [('is', 'VERB'), (('researching', 'X'), ('researching', 'VERB'))],
#  [('is', 'VERB'), (('utterly', 'X'), ('utterly', 'ADV'))],
#  [('utterly', 'ADV'), (('incapable', 'VERB'), ('incapable', 'ADJ'))],
#  [('help', 'VERB'), (('deserving', 'X'), ('deserving', 'ADJ'))],
#  [('some', 'DET'), (('billion-dollar', 'NOUN'), ('billion-dollar', 'ADJ'))],
#  [('Plans', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('and', 'CONJ'), (('underscore', 'NOUN'), ('underscore', 'VERB'))],
#  [('These', 'DET'), (('vertically', 'NOUN'), ('vertically', 'ADV'))],
#  [('integrated', 'VERB'), (('combines', 'VERB'), ('combines', 'NOUN'))],
#  [('their', 'PRON'), (('start', 'VERB'), ('start', 'NOUN'))],
#  [("'s", 'PRT'), (('feudal', 'VERB'), ('feudal', 'ADJ'))],
#  [(',', '.'), (('deal', 'NOUN'), ('deal', 'VERB'))],
#  [('deal', 'VERB'), (('globally', 'NOUN'), ('globally', 'ADV'))],
#  [('and', 'CONJ'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('remains', 'VERB'), (('confident', 'X'), ('confident', 'ADJ'))],
#  [('of', 'ADP'), (('Wilmington', 'DET'), ('Wilmington', 'NOUN'))],
#  [('of', 'ADP'), (('neoprene', 'DET'), ('neoprene', 'NOUN'))],
#  [('by', 'ADP'), (('Blackstone', 'DET'), ('Blackstone', 'NOUN'))],
#  [('are', 'VERB'), (('worth', 'ADJ'), ('worth', 'ADP'))],
#  [('for', 'ADP'), (('aesthetic', 'DET'), ('aesthetic', 'ADJ'))],
#  [('one', 'NUM'), (('famed', 'NOUN'), ('famed', 'ADJ'))],
#  [('a', 'DET'), (('distinct', 'NOUN'), ('distinct', 'ADJ'))],
#  [('car', 'NOUN'), (('routes', 'NOUN'), ('routes', 'VERB'))],
#  [('computer', 'NOUN'), (('file', 'VERB'), ('file', 'NOUN'))],
#  [('file', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('of', 'ADP'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('and', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('Pamplin', 'NOUN'), (('enticed', 'NOUN'), ('enticed', 'VERB'))],
#  [('as', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('move', 'NOUN'), (('befuddled', 'NOUN'), ('befuddled', 'VERB'))],
#  [('What', 'PRON'), (('*T*-164', 'VERB'), ('*T*-164', 'X'))],
#  [('*T*-164', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('is', 'VERB'), (('happening', 'X'), ('happening', 'VERB'))],
#  [('firms', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-255', 'DET'), ('*T*-255', 'X'))],
#  [('of', 'ADP'), (('Charlie', 'DET'), ('Charlie', 'NOUN'))],
#  [('relatively', 'ADV'), (('level', 'NOUN'), ('level', 'ADJ'))],
#  [('which', 'DET'), (('*T*-251', 'NOUN'), ('*T*-251', 'X'))],
#  [('by', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('a', 'DET'), (('slowing', 'NOUN'), ('slowing', 'VERB'))],
#  [('at', 'ADP'), (('Pitney', 'DET'), ('Pitney', 'NOUN'))],
#  [('can', 'VERB'), (('trust', 'NOUN'), ('trust', 'VERB'))],
#  [('$', '.'), (('5.8', 'NOUN'), ('5.8', 'NUM'))],
#  [('was', 'VERB'), (('outraged', 'X'), ('outraged', 'ADJ'))],
#  [('East', 'NOUN'), (('German', 'ADJ'), ('German', 'NOUN'))],
#  [('showing', 'VERB'), (('support', 'VERB'), ('support', 'NOUN'))],
#  [('for', 'ADP'), (('socialism', 'DET'), ('socialism', 'NOUN'))],
#  [('one', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-70', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [("'s", 'VERB'), (('captivating', 'VERB'), ('captivating', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('seem', 'VERB'), (('disagreeable', 'X'), ('disagreeable', 'ADJ'))],
#  [('increasing', 'VERB'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('that', 'ADV'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('*ICH*-1', 'X'), (('Gayle', 'VERB'), ('Gayle', 'NOUN'))],
#  [('incentive', 'NOUN'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('opened', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('can', 'VERB'), ('can', 'NOUN'))],
#  [('of', 'ADP'), (('worms', 'DET'), ('worms', 'NOUN'))],
#  [('of', 'ADP'), (('gallium', 'DET'), ('gallium', 'NOUN'))],
#  [('and', 'CONJ'), (('minute', 'NOUN'), ('minute', 'ADJ'))],
#  [('special', 'ADJ'), (('robotic', 'NOUN'), ('robotic', 'ADJ'))],
#  [('stepped', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('not', 'ADV'), (('panic', 'NOUN'), ('panic', 'VERB'))],
#  [('taken', 'VERB'), (('off', 'PRT'), ('off', 'ADV'))],
#  [('of', 'ADP'), (('home-market', 'DET'), ('home-market', 'ADJ'))],
#  [('home-market', 'ADJ'), (('stock-index', 'ADJ'), ('stock-index', 'NOUN'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('currently', 'ADV'), (('about', 'ADP'), ('about', 'ADV'))],
#  [(',', '.'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('SuperDot', 'NOUN'), (('handles', 'NOUN'), ('handles', 'VERB'))],
#  [('somewhat', 'ADV'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('anticipated', 'VERB'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('prices', 'NOUN'), (('firmed', 'NOUN'), ('firmed', 'VERB'))],
#  [('was', 'VERB'), (('born', 'X'), ('born', 'VERB'))],
#  [('in', 'ADP'), (('Puerto', 'DET'), ('Puerto', 'NOUN'))],
#  [('by', 'ADP'), (('Osborn', 'DET'), ('Osborn', 'NOUN'))],
#  [(',', '.'), (('benefits', 'NOUN'), ('benefits', 'VERB'))],
#  [('the', 'DET'), (('backing', 'VERB'), ('backing', 'NOUN'))],
#  [('1,000', 'NUM'), (('enclosed', 'NOUN'), ('enclosed', 'VERB'))],
#  [('transporting', 'VERB'), (('autos', 'X'), ('autos', 'NOUN'))],
#  [('years', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('.', '.'), (('Mostly', 'NOUN'), ('Mostly', 'ADV'))],
#  [('to', 'PRT'), (('self-esteem', 'VERB'), ('self-esteem', 'NOUN'))],
#  [('the', 'DET'), (('Second', 'ADJ'), ('Second', 'NOUN'))],
#  [('of', 'ADP'), (('Appeals', 'DET'), ('Appeals', 'NOUN'))],
#  [('for', 'ADP'), (('Jail', 'DET'), ('Jail', 'NOUN'))],
#  [('Solution', 'NOUN'), (('Fails', 'NOUN'), ('Fails', 'VERB'))],
#  [('Take', 'VERB'), (('Root', 'X'), ('Root', 'NOUN'))],
#  [('which', 'DET'), (('*T*-148', 'NOUN'), ('*T*-148', 'X'))],
#  [('expanding', 'VERB'),
#   (('manufacturing', 'VERB'), ('manufacturing', 'NOUN'))],
#  [('took', 'VERB'), (('refuge', 'X'), ('refuge', 'NOUN'))],
#  [('to', 'PRT'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('of', 'ADP'), (('major-league', 'DET'), ('major-league', 'ADJ'))],
#  [('recent', 'ADJ'), (('closing', 'ADJ'), ('closing', 'NOUN'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('the', 'DET'), (('Andean', 'NOUN'), ('Andean', 'ADJ'))],
#  [('investors', 'NOUN'), (('spooked', 'NOUN'), ('spooked', 'VERB'))],
#  [('seem', 'VERB'), (('far', 'ADV'), ('far', 'ADJ'))],
#  [('far', 'ADJ'), (('drearier', 'VERB'), ('drearier', 'ADV'))],
#  [('a', 'DET'), (('vitriolic', 'NOUN'), ('vitriolic', 'ADJ'))],
#  [('A', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('every', 'DET'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('be', 'VERB'), (('fluent', 'X'), ('fluent', 'ADJ'))],
#  [('sold', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('Kodansha', 'NOUN'), (('published', 'NOUN'), ('published', 'VERB'))],
#  [('who', 'PRON'), (('*T*-103', 'VERB'), ('*T*-103', 'X'))],
#  [('presidents', 'NOUN'), (('*PPA*-1', 'NOUN'), ('*PPA*-1', 'X'))],
#  [('have', 'VERB'), (('shared', 'X'), ('shared', 'VERB'))],
#  [('such', 'ADJ'), (('lawmaking', 'NOUN'), ('lawmaking', 'ADJ'))],
#  [('of', 'ADP'), (('Dunkin', 'DET'), ('Dunkin', 'NOUN'))],
#  [('Dunkin', 'NOUN'), (("'s", 'VERB'), ("'s", 'PRT'))],
#  [('ownership', 'NOUN'), (('plans', 'VERB'), ('plans', 'NOUN'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('to', 'PRT'), (('American-style', 'VERB'), ('American-style', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-253', 'DET'), ('*T*-253', 'X'))],
#  [('leading', 'VERB'), (('Sauternes', 'X'), ('Sauternes', 'NOUN'))],
#  [('well', 'ADV'), (('over', 'ADP'), ('over', 'ADV'))],
#  [('a', 'DET'), (('lighter', 'NOUN'), ('lighter', 'ADJ'))],
#  [('the', 'DET'), (('spectacularly', 'NOUN'), ('spectacularly', 'ADV'))],
#  [('but', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('main', 'ADJ'), (('index-arbitrage', 'ADJ'), ('index-arbitrage', 'NOUN'))],
#  [('``', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('information', 'NOUN'),
#   (('domestically', 'NOUN'), ('domestically', 'ADV'))],
#  [('though', 'ADP'), (('exhaust', 'DET'), ('exhaust', 'NOUN'))],
#  [('fans', 'NOUN'), (('ventilated', 'NOUN'), ('ventilated', 'VERB'))],
#  [('their', 'PRON'), (('monopoly', 'VERB'), ('monopoly', 'NOUN'))],
#  [('too', 'ADV'), (('upset', 'VERB'), ('upset', 'ADJ'))],
#  [('by', 'ADP'), (('Economy', 'DET'), ('Economy', 'NOUN'))],
#  [('is', 'VERB'), (('derived', 'X'), ('derived', 'VERB'))],
#  [('banks', 'NOUN'), (('exhaust', 'NOUN'), ('exhaust', 'VERB'))],
#  [('ruling', 'NOUN'), (('work', 'NOUN'), ('work', 'VERB'))],
#  [('could', 'VERB'), (('intimidate', 'X'), ('intimidate', 'VERB'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('``', '.'), (('Provided', 'NOUN'), ('Provided', 'VERB'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('all', 'DET'), (('pension-fund', 'NOUN'), ('pension-fund', 'ADJ'))],
#  [('managers', 'NOUN'), (('ranked', 'NOUN'), ('ranked', 'VERB'))],
#  [("'s", 'PRT'), (('offering', 'VERB'), ('offering', 'NOUN'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('are', 'VERB'), (('infrequent', 'X'), ('infrequent', 'ADJ'))],
#  [('the', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('In', 'ADP'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [('fell', 'VERB'), (('63.79', 'X'), ('63.79', 'NUM'))],
#  [('to', 'PRT'), (('35500.64', 'VERB'), ('35500.64', 'NUM'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('Hills', 'NOUN'), (('lauded', 'NOUN'), ('lauded', 'VERB'))],
#  [('copper', 'NOUN'), (('mine', 'ADJ'), ('mine', 'NOUN'))],
#  [('been', 'VERB'), (('inoperative', 'X'), ('inoperative', 'ADJ'))],
#  [('by', 'ADP'), (('native', 'DET'), ('native', 'ADJ'))],
#  [('*U*', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('play', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NOUN'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('unwanted', 'ADJ'), (('suitors', 'X'), ('suitors', 'NOUN'))],
#  [('to', 'PRT'), (('audit', 'NOUN'), ('audit', 'VERB'))],
#  [('and', 'CONJ'), (('refund', 'NOUN'), ('refund', 'VERB'))],
#  [('partly', 'ADV'), (('one', 'NUM'), ('one', 'NOUN'))],
#  [(',', '.'), (('English', 'NOUN'), ('English', 'ADJ'))],
#  [('its', 'PRON'), (('satisfaction', 'VERB'), ('satisfaction', 'NOUN'))],
#  [('in', 'ADP'), (('mathematical', 'DET'), ('mathematical', 'ADJ'))],
#  [('a', 'DET'), (('tremendous', 'NOUN'), ('tremendous', 'ADJ'))],
#  [(',', '.'), (('tight', 'ADV'), ('tight', 'ADJ'))],
#  [('tight', 'ADJ'), (('facial', 'VERB'), ('facial', 'ADJ'))],
#  [('facial', 'ADJ'), (('shot', 'VERB'), ('shot', 'NOUN'))],
#  [('.', '.'), (('Above', 'NOUN'), ('Above', 'ADP'))],
#  [('extremely', 'ADV'), (('confused', 'ADJ'), ('confused', 'VERB'))],
#  [('is', 'VERB'), (('furious', 'X'), ('furious', 'ADJ'))],
#  [('was', 'VERB'), (('chastised', 'X'), ('chastised', 'VERB'))],
#  [('``', '.'), (('In', 'ADP'), ('In', 'NOUN'))],
#  [('would', 'VERB'), (('assess', 'X'), ('assess', 'VERB'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('at', 'ADP'), (('mid-afternoon', 'DET'), ('mid-afternoon', 'ADJ'))],
#  [('at', 'ADP'), (('260', 'DET'), ('260', 'NUM'))],
#  [('``', '.'), (('melt-textured', 'NOUN'), ('melt-textured', 'ADJ'))],
#  [('*', 'X'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('due', 'ADJ'), (('1995', 'NOUN'), ('1995', 'NUM'))],
#  [('fell', 'VERB'), (('9\\/32', 'X'), ('9\\/32', 'NUM'))],
#  [('to', 'PRT'), (('103', 'VERB'), ('103', 'NUM'))],
#  [('yield', 'VERB'), (('11.10', 'X'), ('11.10', 'NUM'))],
#  [('keep', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('S&P', 'NOUN'), (('Following', 'NOUN'), ('Following', 'VERB'))],
#  [('a', 'DET'), (('buy-out', 'NOUN'), ('buy-out', 'ADJ'))],
#  [('Hutton', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('of', 'ADP'), (('gelatin', 'DET'), ('gelatin', 'NOUN'))],
#  [('its', 'PRON'),
#   (('non-encapsulating', 'VERB'), ('non-encapsulating', 'ADJ'))],
#  [('For', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('his', 'PRON'), (('destination', 'VERB'), ('destination', 'NOUN'))],
#  [('commercials', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*U*', 'X'), (('write-off', 'VERB'), ('write-off', 'NOUN'))],
#  [('capitalized', 'VERB'), (('servicing', 'X'), ('servicing', 'NOUN'))],
#  [('home', 'NOUN'), (('financing', 'NOUN'), ('financing', 'VERB'))],
#  [('The', 'DET'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [("'s", 'PRT'), (('offerings', 'VERB'), ('offerings', 'NOUN'))],
#  [('early', 'ADJ'), (('1980s', 'NUM'), ('1980s', 'NOUN'))],
#  [('its', 'PRON'), (('glory', 'VERB'), ('glory', 'NOUN'))],
#  [('had', 'VERB'), (('faded', 'X'), ('faded', 'VERB'))],
#  [('the', 'DET'), (('yellow', 'NOUN'), ('yellow', 'ADJ'))],
#  [('their', 'PRON'), (('farms', 'VERB'), ('farms', 'NOUN'))],
#  [('``', '.'), (('Nasty', 'NOUN'), ('Nasty', 'ADJ'))],
#  [('corruption', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("''", '.'), (('High', 'NOUN'), ('High', 'ADJ'))],
#  [('--', '.'), (('a', 'DET'), ('a', 'ADP'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('funds', 'NOUN'), (('tracked', 'NOUN'), ('tracked', 'VERB'))],
#  [('by', 'ADP'), (('IBC', 'DET'), ('IBC', 'NOUN'))],
#  [('IBC', 'NOUN'), (("'s", 'VERB'), ("'s", 'PRT'))],
#  [('a', 'DET'), (('labor-backed', 'NOUN'), ('labor-backed', 'ADJ'))],
#  [('amendment', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('purchase', 'NOUN'), ('purchase', 'VERB'))],
#  [('previously', 'ADV'), (('that', 'ADP'), ('that', 'DET'))],
#  [('.', '.'), (('Against', 'NOUN'), ('Against', 'ADP'))],
#  [('a', 'DET'), (('shot', 'VERB'), ('shot', 'NOUN'))],
#  [('of', 'ADP'), (('Monticello', 'DET'), ('Monticello', 'NOUN'))],
#  [('Monticello', 'NOUN'),
#   (('superimposed', 'NOUN'), ('superimposed', 'VERB'))],
#  [('announcer', 'NOUN'), (('talks', 'NOUN'), ('talks', 'VERB'))],
#  [("''", '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('have', 'VERB'), (('nurtured', 'X'), ('nurtured', 'VERB'))],
#  [('for', 'ADP'), (('generations', 'DET'), ('generations', 'NOUN'))]]

# %%
#runnnig the algorithm on the validation data

start = time.time()
tagged_seq_validation_1 = viterbi_modification_1(validation_token)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 27.765124320983887

# %%
tagged_seq_validation_1
# Out:
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'DET'),
#  ('.', '.'),
#  ('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'DET'),
#  ('since', 'ADP'),
#  ('2011', 'DET'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'DET'),
#  ('.', '.'),
#  ('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'DET'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'X'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'VERB'),
#  ("'s", 'PRT'),
#  ('firehose', 'VERB'),
#  ('.', '.'),
#  ('Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'DET'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'DET'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'NOUN'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'DET'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# ### Observations from the Validation set
#
# - The situation has improvied a bit, this is also seen by the accuracy (~93%).
# - But still, some words like google, smartphones are tagged as determinents.
# - Numbers still has issues

# %% [markdown]
# ## Modification #2
#
# _I this case, using a Unigram tagger along with a regex tagger to supplement the veterbi algorithm_

# %%
def viterbi_modification_2(words, train_bag = train_tagged_words):
    
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    patterns = [
    (r'.*ing$', 'VERB'),
    (r'.*ed$', 'VERB'),  
    (r'.*es$', 'VERB'),
    (r'.*ould$', 'VERB'), 
    (r'.*\'s$', 'PRT'),               
    (r'.*s$', 'NOUN'), 
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'),
    (r'.*', 'NOUN')]

    regexp_tagger = nltk.RegexpTagger(patterns)

# lexicon backed up by the rule-based tagger
    lexicon_tagger = nltk.UnigramTagger(train_set, backoff=regexp_tagger)

    #lexicon_tagger.evaluate(incorrect_tag_word)
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        state_max = T[p.index(pmax)]
        #state_max = []
        if (pmax == 0):
            
            new_tag = lexicon_tagger.tag((word,state_max))
            
            state_max = new_tag[0][1]
            
        state.append(state_max)
    return list(zip(words, state))

# %%
start = time.time()
tagged_seq_2 = viterbi_modification_2(test_tagged_words)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 798.3143727779388

# %%
check_2 = [i for i, j in zip(tagged_seq_2, test_run_base) if i == j]
print(len(check_2))
print(len(test_run_base))
print(len(tagged_seq_2))
# Out:
# 4825
# 5081
# 5081

# %%
accuracy_modification_2 = len(check_2)/len(tagged_seq_2)
accuracy_modification_2
# Out:
# 0.949616217280063

# %%
#checking the incorrected tags in the test data to check the problems
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq_2, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[("n't", 'ADV'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('Italy', 'NOUN'), (('there', 'DET'), ('there', 'ADV'))],
#  [('``', '.'), (('genuine', 'NOUN'), ('genuine', 'ADJ'))],
#  [('this', 'DET'), (('touchy', 'NOUN'), ('touchy', 'ADJ'))],
#  [('pay', 'VERB'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('for', 'ADP'), (('free', 'ADJ'), ('free', 'ADV'))],
#  [('No', 'DET'), (('one', 'NUM'), ('one', 'NOUN'))],
#  [(',', '.'), (('though', 'ADP'), ('though', 'ADV'))],
#  [('such', 'ADJ'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('acquiring', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('.', '.'), (('Arbitrage-related', 'VERB'), ('Arbitrage-related', 'ADJ'))],
#  [('of', 'ADP'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('the', 'DET'), (('close', 'ADJ'), ('close', 'NOUN'))],
#  [('to', 'PRT'), (('augment', 'NOUN'), ('augment', 'VERB'))],
#  [('buy', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('company', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-146', 'NOUN'), ('*T*-146', 'X'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('budding', 'VERB'), (('logistical', 'NOUN'), ('logistical', 'ADJ'))],
#  [('of', 'ADP'), (('punitive', 'NOUN'), ('punitive', 'ADJ'))],
#  [('to', 'PRT'), (('license', 'NOUN'), ('license', 'VERB'))],
#  [('an', 'DET'), (('anti-miscarriage', 'NOUN'), ('anti-miscarriage', 'ADJ'))],
#  [('sell', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('stock', 'NOUN'), (('short', 'ADJ'), ('short', 'ADV'))],
#  [('buying', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('0', 'X'), (('export', 'VERB'), ('export', 'NOUN'))],
#  [('month', 'NOUN'), (('before', 'ADP'), ('before', 'ADV'))],
#  [('its', 'PRON'), (('F-series', 'VERB'), ('F-series', 'NOUN'))],
#  [('ads', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('The', 'DET'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('of', 'ADP'), (('Delegates', 'VERB'), ('Delegates', 'NOUN'))],
#  [('IRS', 'NOUN'), (('reporting', 'VERB'), ('reporting', 'NOUN'))],
#  [('send', 'VERB'), (('continuously', 'NOUN'), ('continuously', 'ADV'))],
#  [('colored', 'VERB'), (('light', 'ADJ'), ('light', 'NOUN'))],
#  [('of', 'ADP'), (('fiber-end', 'NOUN'), ('fiber-end', 'ADJ'))],
#  [('fiber-end', 'ADJ'), (('bunches', 'VERB'), ('bunches', 'NOUN'))],
#  [('how', 'ADV'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('the', 'DET'), (('very', 'ADV'), ('very', 'ADJ'))],
#  [('very', 'ADJ'), (('building', 'VERB'), ('building', 'NOUN'))],
#  [('*ICH*-4', 'X'), (('that', 'ADP'), ('that', 'DET'))],
#  [('as', 'ADP'), (('chief', 'NOUN'), ('chief', 'ADJ'))],
#  [('assumed', 'VERB'), (('*-121', 'NOUN'), ('*-121', 'X'))],
#  [('risen', 'VERB'), (('smartly', 'NOUN'), ('smartly', 'ADV'))],
#  [('with', 'ADP'), (('even', 'ADV'), ('even', 'ADJ'))],
#  [('.', '.'), (('Recently', 'NOUN'), ('Recently', 'ADV'))],
#  [('When', 'ADV'), (('test', 'VERB'), ('test', 'NOUN'))],
#  [('*-1', 'X'), (('out', 'PRT'), ('out', 'ADV'))],
#  [('and', 'CONJ'), (('pipes', 'VERB'), ('pipes', 'NOUN'))],
#  [('plant', 'NOUN'), (('engineering', 'NOUN'), ('engineering', 'VERB'))],
#  [("'s", 'PRT'), (('work', 'VERB'), ('work', 'NOUN'))],
#  [('broken', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [("'s", 'PRT'), (('nine-year', 'NOUN'), ('nine-year', 'ADJ'))],
#  [('nearly', 'ADV'), (('tenfold', 'NOUN'), ('tenfold', 'ADV'))],
#  [("'s", 'PRT'), (('launch', 'VERB'), ('launch', 'NOUN'))],
#  [('a', 'DET'), (('darned', 'VERB'), ('darned', 'ADV'))],
#  [('Assuming', 'VERB'), (('that', 'ADP'), ('that', 'DET'))],
#  [('in', 'ADP'), (('universities', 'VERB'), ('universities', 'NOUN'))],
#  [('now', 'ADV'), (('understands', 'NOUN'), ('understands', 'VERB'))],
#  [('is', 'VERB'), (('utterly', 'NOUN'), ('utterly', 'ADV'))],
#  [('utterly', 'ADV'), (('incapable', 'NOUN'), ('incapable', 'ADJ'))],
#  [('help', 'VERB'), (('deserving', 'VERB'), ('deserving', 'ADJ'))],
#  [('some', 'DET'), (('billion-dollar', 'NOUN'), ('billion-dollar', 'ADJ'))],
#  [('Plans', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('permanent', 'ADJ'), (('fixtures', 'VERB'), ('fixtures', 'NOUN'))],
#  [('and', 'CONJ'), (('underscore', 'NOUN'), ('underscore', 'VERB'))],
#  [('These', 'DET'), (('vertically', 'NOUN'), ('vertically', 'ADV'))],
#  [('integrated', 'VERB'), (('combines', 'VERB'), ('combines', 'NOUN'))],
#  [('their', 'PRON'), (('start', 'VERB'), ('start', 'NOUN'))],
#  [("'s", 'PRT'), (('feudal', 'NOUN'), ('feudal', 'ADJ'))],
#  [(',', '.'), (('deal', 'NOUN'), ('deal', 'VERB'))],
#  [('deal', 'VERB'), (('globally', 'NOUN'), ('globally', 'ADV'))],
#  [('and', 'CONJ'), (('manufacturing', 'NOUN'), ('manufacturing', 'VERB'))],
#  [('remains', 'VERB'), (('confident', 'NOUN'), ('confident', 'ADJ'))],
#  [('put', 'VERB'), (('*-41', 'NOUN'), ('*-41', 'X'))],
#  [('*-41', 'X'), (('together', 'ADV'), ('together', 'PRT'))],
#  [('are', 'VERB'), (('worth', 'ADJ'), ('worth', 'ADP'))],
#  [('for', 'ADP'), (('aesthetic', 'NOUN'), ('aesthetic', 'ADJ'))],
#  [('one', 'NUM'), (('famed', 'VERB'), ('famed', 'ADJ'))],
#  [('a', 'DET'), (('distinct', 'NOUN'), ('distinct', 'ADJ'))],
#  [('computer', 'NOUN'), (('file', 'VERB'), ('file', 'NOUN'))],
#  [('file', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-1', 'X'), (('scans', 'NOUN'), ('scans', 'VERB'))],
#  [('of', 'ADP'), (('buy', 'VERB'), ('buy', 'NOUN'))],
#  [('and', 'CONJ'), (('sell', 'VERB'), ('sell', 'NOUN'))],
#  [('as', 'ADP'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('What', 'PRON'), (('*T*-164', 'NOUN'), ('*T*-164', 'X'))],
#  [('*T*-164', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('firms', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-255', 'NOUN'), ('*T*-255', 'X'))],
#  [('relatively', 'ADV'), (('level', 'NOUN'), ('level', 'ADJ'))],
#  [('which', 'DET'), (('*T*-251', 'NOUN'), ('*T*-251', 'X'))],
#  [('by', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('a', 'DET'), (('slowing', 'NOUN'), ('slowing', 'VERB'))],
#  [('Pitney', 'NOUN'), (('Bowes', 'VERB'), ('Bowes', 'NOUN'))],
#  [('can', 'VERB'), (('trust', 'NOUN'), ('trust', 'VERB'))],
#  [('the', 'DET'), (('Monopolies', 'VERB'), ('Monopolies', 'NOUN'))],
#  [('replacement', 'NOUN'), (('tires', 'VERB'), ('tires', 'NOUN'))],
#  [('was', 'VERB'), (('outraged', 'VERB'), ('outraged', 'ADJ'))],
#  [('dominated', 'VERB'), (('*-41', 'NOUN'), ('*-41', 'X'))],
#  [('East', 'NOUN'), (('German', 'ADJ'), ('German', 'NOUN'))],
#  [('showing', 'VERB'), (('support', 'VERB'), ('support', 'NOUN'))],
#  [('one', 'NUM'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-70', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [("'s", 'VERB'), (('captivating', 'VERB'), ('captivating', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('seem', 'VERB'), (('disagreeable', 'NOUN'), ('disagreeable', 'ADJ'))],
#  [('increasing', 'VERB'), (('that', 'ADP'), ('that', 'ADV'))],
#  [('that', 'ADV'), (('much', 'ADJ'), ('much', 'ADV'))],
#  [('incentive', 'NOUN'), (('pay', 'VERB'), ('pay', 'NOUN'))],
#  [('opened', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('can', 'VERB'), ('can', 'NOUN'))],
#  [('and', 'CONJ'), (('minute', 'NOUN'), ('minute', 'ADJ'))],
#  [('special', 'ADJ'), (('robotic', 'NOUN'), ('robotic', 'ADJ'))],
#  [('stepped', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('not', 'ADV'), (('panic', 'NOUN'), ('panic', 'VERB'))],
#  [('taken', 'VERB'), (('off', 'PRT'), ('off', 'ADV'))],
#  [('of', 'ADP'), (('home-market', 'NOUN'), ('home-market', 'ADJ'))],
#  [('make', 'VERB'), (('such', 'ADJ'), ('such', 'DET'))],
#  [('currently', 'ADV'), (('about', 'ADP'), ('about', 'ADV'))],
#  [(',', '.'), (('up', 'ADV'), ('up', 'ADP'))],
#  [('.', '.'), (('So', 'ADV'), ('So', 'ADP'))],
#  [('to', 'PRT'), (('zip', 'NOUN'), ('zip', 'VERB'))],
#  [('somewhat', 'ADV'), (('better', 'ADV'), ('better', 'ADJ'))],
#  [('anticipated', 'VERB'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('to', 'PRT'), (('arrive', 'NOUN'), ('arrive', 'VERB'))],
#  [('was', 'VERB'), (('born', 'NOUN'), ('born', 'VERB'))],
#  [(',', '.'), (('benefits', 'NOUN'), ('benefits', 'VERB'))],
#  [('the', 'DET'), (('backing', 'VERB'), ('backing', 'NOUN'))],
#  [('years', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('.', '.'), (('Mostly', 'NOUN'), ('Mostly', 'ADV'))],
#  [('the', 'DET'), (('Second', 'ADJ'), ('Second', 'NOUN'))],
#  [('.', '.'), (('Seed', 'VERB'), ('Seed', 'NOUN'))],
#  [('Solution', 'NOUN'), (('Fails', 'NOUN'), ('Fails', 'VERB'))],
#  [('which', 'DET'), (('*T*-148', 'NOUN'), ('*T*-148', 'X'))],
#  [('expanding', 'VERB'),
#   (('manufacturing', 'VERB'), ('manufacturing', 'NOUN'))],
#  [('to', 'PRT'), (('pressure', 'NOUN'), ('pressure', 'VERB'))],
#  [('of', 'ADP'), (('major-league', 'NOUN'), ('major-league', 'ADJ'))],
#  [('recent', 'ADJ'), (('closing', 'ADJ'), ('closing', 'NOUN'))],
#  [('often', 'ADV'), (('buys', 'NOUN'), ('buys', 'VERB'))],
#  [('reported', 'VERB'), (('declines', 'VERB'), ('declines', 'NOUN'))],
#  [('drug', 'NOUN'), (('trafficking', 'VERB'), ('trafficking', 'NOUN'))],
#  [('the', 'DET'), (('Andean', 'NOUN'), ('Andean', 'ADJ'))],
#  [('.', '.'), (('Packages', 'VERB'), ('Packages', 'NOUN'))],
#  [('seem', 'VERB'), (('far', 'ADV'), ('far', 'ADJ'))],
#  [('far', 'ADJ'), (('drearier', 'NOUN'), ('drearier', 'ADV'))],
#  [('to', 'PRT'), (('tuck', 'NOUN'), ('tuck', 'VERB'))],
#  [('a', 'DET'), (('vitriolic', 'NOUN'), ('vitriolic', 'ADJ'))],
#  [('A', 'DET'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('every', 'DET'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('be', 'VERB'), (('fluent', 'NOUN'), ('fluent', 'ADJ'))],
#  [('sold', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-103', 'NOUN'), ('*T*-103', 'X'))],
#  [('presidents', 'NOUN'), (('*PPA*-1', 'NOUN'), ('*PPA*-1', 'X'))],
#  [('such', 'ADJ'), (('lawmaking', 'VERB'), ('lawmaking', 'ADJ'))],
#  [('ownership', 'NOUN'), (('plans', 'VERB'), ('plans', 'NOUN'))],
#  [('to', 'PRT'), (('deter', 'NOUN'), ('deter', 'VERB'))],
#  [('*', 'X'), (('Compare', 'NOUN'), ('Compare', 'VERB'))],
#  [('adds', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('to', 'PRT'), (('American-style', 'NOUN'), ('American-style', 'ADJ'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('trading', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-253', 'NOUN'), ('*T*-253', 'X'))],
#  [('to', 'PRT'), (('exploit', 'NOUN'), ('exploit', 'VERB'))],
#  [('exploit', 'VERB'), (('brief', 'VERB'), ('brief', 'ADJ'))],
#  [('leading', 'VERB'), (('Sauternes', 'VERB'), ('Sauternes', 'NOUN'))],
#  [('well', 'ADV'), (('over', 'ADP'), ('over', 'ADV'))],
#  [('a', 'DET'), (('lighter', 'NOUN'), ('lighter', 'ADJ'))],
#  [('the', 'DET'), (('spectacularly', 'NOUN'), ('spectacularly', 'ADV'))],
#  [('but', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('main', 'ADJ'), (('index-arbitrage', 'ADJ'), ('index-arbitrage', 'NOUN'))],
#  [('``', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('to', 'PRT'), (('preclude', 'NOUN'), ('preclude', 'VERB'))],
#  [('information', 'NOUN'),
#   (('domestically', 'NOUN'), ('domestically', 'ADV'))],
#  [('*T*-1', 'X'), (('hung', 'NOUN'), ('hung', 'VERB'))],
#  [('too', 'ADV'), (('upset', 'VERB'), ('upset', 'ADJ'))],
#  [('banks', 'NOUN'), (('exhaust', 'NOUN'), ('exhaust', 'VERB'))],
#  [('all', 'DET'), (('avenues', 'VERB'), ('avenues', 'NOUN'))],
#  [('ruling', 'NOUN'), (('work', 'NOUN'), ('work', 'VERB'))],
#  [('could', 'VERB'), (('intimidate', 'NOUN'), ('intimidate', 'VERB'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [(',', '.'), (('that', 'DET'), ('that', 'ADP'))],
#  [('all', 'DET'), (('pension-fund', 'NOUN'), ('pension-fund', 'ADJ'))],
#  [("'s", 'PRT'), (('offering', 'VERB'), ('offering', 'NOUN'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('are', 'VERB'), (('infrequent', 'NOUN'), ('infrequent', 'ADJ'))],
#  [('the', 'DET'), (('future', 'ADJ'), ('future', 'NOUN'))],
#  [('In', 'ADP'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('book', 'NOUN'), (('pirates', 'VERB'), ('pirates', 'NOUN'))],
#  [('copper', 'NOUN'), (('mine', 'ADJ'), ('mine', 'NOUN'))],
#  [('been', 'VERB'), (('inoperative', 'NOUN'), ('inoperative', 'ADJ'))],
#  [('by', 'ADP'), (('native', 'NOUN'), ('native', 'ADJ'))],
#  [('to', 'PRT'), (('secede', 'NOUN'), ('secede', 'VERB'))],
#  [('perceives', 'VERB'), (('*T*-183', 'NOUN'), ('*T*-183', 'X'))],
#  [('*U*', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('play', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('a', 'DET'),
#   (('shareholder-rights', 'NOUN'), ('shareholder-rights', 'ADJ'))],
#  [('off', 'PRT'), (('unwanted', 'VERB'), ('unwanted', 'ADJ'))],
#  [('to', 'PRT'), (('audit', 'NOUN'), ('audit', 'VERB'))],
#  [('and', 'CONJ'), (('refund', 'NOUN'), ('refund', 'VERB'))],
#  [('not', 'ADV'), (('prescribe', 'NOUN'), ('prescribe', 'VERB'))],
#  [('to', 'PRT'), (('assure', 'NOUN'), ('assure', 'VERB'))],
#  [('partly', 'ADV'), (('one', 'NUM'), ('one', 'NOUN'))],
#  [(',', '.'), (('English', 'NOUN'), ('English', 'ADJ'))],
#  [('*T*-1', 'X'), (('finds', 'NOUN'), ('finds', 'VERB'))],
#  [('in', 'ADP'), (('mathematical', 'NOUN'), ('mathematical', 'ADJ'))],
#  [('a', 'DET'), (('tremendous', 'NOUN'), ('tremendous', 'ADJ'))],
#  [(',', '.'), (('tight', 'ADV'), ('tight', 'ADJ'))],
#  [('tight', 'ADJ'), (('facial', 'NOUN'), ('facial', 'ADJ'))],
#  [('facial', 'ADJ'), (('shot', 'VERB'), ('shot', 'NOUN'))],
#  [('to', 'PRT'), (('implant', 'NOUN'), ('implant', 'VERB'))],
#  [('.', '.'), (('Above', 'NOUN'), ('Above', 'ADP'))],
#  [('extremely', 'ADV'), (('confused', 'ADJ'), ('confused', 'VERB'))],
#  [('is', 'VERB'), (('furious', 'NOUN'), ('furious', 'ADJ'))],
#  [('``', '.'), (('In', 'ADP'), ('In', 'NOUN'))],
#  [('would', 'VERB'), (('assess', 'NOUN'), ('assess', 'VERB'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('at', 'ADP'), (('mid-afternoon', 'NOUN'), ('mid-afternoon', 'ADJ'))],
#  [('to', 'PRT'), (('combine', 'NOUN'), ('combine', 'VERB'))],
#  [('``', '.'), (('melt-textured', 'VERB'), ('melt-textured', 'ADJ'))],
#  [('*', 'X'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('fell', 'VERB'), (('9\\/32', 'NOUN'), ('9\\/32', 'NUM'))],
#  [('keep', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('a', 'DET'), (('buy-out', 'NOUN'), ('buy-out', 'ADJ'))],
#  [('Hutton', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('gelatin', 'NOUN'), (('capsules', 'VERB'), ('capsules', 'NOUN'))],
#  [('to', 'PRT'), (('divest', 'NOUN'), ('divest', 'VERB'))],
#  [('its', 'PRON'),
#   (('non-encapsulating', 'VERB'), ('non-encapsulating', 'ADJ'))],
#  [('For', 'ADP'), (('American', 'ADJ'), ('American', 'NOUN'))],
#  [('to', 'PRT'), (('broaden', 'NOUN'), ('broaden', 'VERB'))],
#  [('to', 'PRT'), (('fly', 'NOUN'), ('fly', 'VERB'))],
#  [('they', 'PRON'), (('fly', 'NOUN'), ('fly', 'VERB'))],
#  [('commercials', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('capitalized', 'VERB'), (('servicing', 'VERB'), ('servicing', 'NOUN'))],
#  [('home', 'NOUN'), (('financing', 'NOUN'), ('financing', 'VERB'))],
#  [('The', 'DET'), (('following', 'NOUN'), ('following', 'VERB'))],
#  [('early', 'ADJ'), (('1980s', 'NUM'), ('1980s', 'NOUN'))],
#  [('glory', 'NOUN'), (('*PPA*-1', 'NOUN'), ('*PPA*-1', 'X'))],
#  [('the', 'DET'), (('yellow', 'NOUN'), ('yellow', 'ADJ'))],
#  [('``', '.'), (('Nasty', 'NOUN'), ('Nasty', 'ADJ'))],
#  [('Nasty', 'ADJ'), (('innuendoes', 'VERB'), ('innuendoes', 'NOUN'))],
#  [('to', 'PRT'), (('prosecute', 'NOUN'), ('prosecute', 'VERB'))],
#  [('corruption', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [("''", '.'), (('High', 'NOUN'), ('High', 'ADJ'))],
#  [('--', '.'), (('a', 'DET'), ('a', 'ADP'))],
#  [('compound', 'NOUN'), (('yield', 'VERB'), ('yield', 'NOUN'))],
#  [('a', 'DET'), (('labor-backed', 'VERB'), ('labor-backed', 'ADJ'))],
#  [('amendment', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('to', 'PRT'), (('purchase', 'NOUN'), ('purchase', 'VERB'))],
#  [('previously', 'ADV'), (('that', 'ADP'), ('that', 'DET'))],
#  [('questionable', 'ADJ'), (('properties', 'VERB'), ('properties', 'NOUN'))],
#  [('.', '.'), (('Against', 'NOUN'), ('Against', 'ADP'))],
#  [('a', 'DET'), (('shot', 'VERB'), ('shot', 'NOUN'))],
#  [('announcer', 'NOUN'), (('talks', 'NOUN'), ('talks', 'VERB'))],
#  [("''", '.'), (('that', 'DET'), ('that', 'ADP'))]]

# %%
#runnnig the algorithm on the validation data

start = time.time()
tagged_seq_validation_2 = viterbi_modification_2(validation_token)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 29.496506690979004

# %%
tagged_seq_validation_2
# Out:
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'NOUN'),
#  ('.', '.'),
#  ('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'VERB'),
#  ('since', 'ADP'),
#  ('2011', 'NUM'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'NUM'),
#  ('.', '.'),
#  ('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NUM'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('firehose', 'NOUN'),
#  ('.', '.'),
#  ('Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'VERB'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'NOUN'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'VERB'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'NUM'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'VERB'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'VERB'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'NOUN'),
#  ('invited', 'VERB'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# ### Observations from Method 2
# - The situation has improved quite a lot (~95%)
# - The baseline Viterbe algorithm gives an accuracy of 91%, where as method 1 & method 2, increases this.
# - The numbers are identified correctly.
# - Android, Google, twitter etc has been **identified correctly by method 2**

# %% [markdown]
# ### Comaparison from Baseline Veterbi
#
# - The baseline verterbi methods proves as a good starting point, but doesn't performs well on unknown items.
# - The basic problem with unknown words is, the algorithm give "0" probability as the emission probabilities are not known.
# - By assuming on transitional probabilies for the unknow words the sitution improves (93% accracy).
# - Finally, the minor issues are resolved by the unigram & regrex Tagger & hence the model improves further (~95% accuracy)
